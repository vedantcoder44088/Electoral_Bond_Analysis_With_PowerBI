# %%
import os
import pandas as pd
os.getcwd()
# Out:
# '/Users/vedantpatel/Documents/Data Analysis Bootcamp/Day-6'

# %%
doners_data = pd.read_excel(r"donors_data.xlsx")
receiver_data = pd.read_excel(r"redemption_data.xlsx")

# %%
doners_data.head()
# Out:
#    Sr No.      Reference No  (URN) Journal Date Date of\nPurchase  \
# 0       1  00001201904120000001166   2019-04-12        2019-04-12
# 1       2  00001201904120000001166   2019-04-12        2019-04-12
# 2       3  00001201904120000001166   2019-04-12        2019-04-12
# 3       4  00001201904120000001166   2019-04-12        2019-04-12
# 4       5  00001201904120000001166   2019-04-12        2019-04-12
#
#   Date of Expiry Name of the Purchaser Prefix  Bond\nNumber  Denominations  \
# 0     2019-04-26   A B C INDIA LIMITED     TL         11448        1000000
# 1     2019-04-26   A B C INDIA LIMITED     TL         11447        1000000
# 2     2019-04-26   A B C INDIA LIMITED     TL         11441        1000000
# 3     2019-04-26   A B C INDIA LIMITED     OL          1113         100000
# 4     2019-04-26   A B C INDIA LIMITED     OL          1118         100000
#
#    Issue Branch Code  Issue Teller Status
# 0                  1       5899230   Paid
# ...

# %%
receiver_data.head()
# Out:
#    Sr No. Date of\nEncashment               Name of the Political Party  \
# 0       1          2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 1       2          2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 2       3          2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 3       4          2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 4       5          2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
#
#   Account no. of\nPolitical Party Prefix  Bond\nNumber  Denominations  \
# 0                     *******5199     OC           775       10000000
# 1                     *******5199     OC          3975       10000000
# 2                     *******5199     OC          3967       10000000
# 3                     *******5199     TL         10418        1000000
# 4                     *******5199     TL           126        1000000
#
#    Pay Branch\nCode  Pay Teller
# 0               800     2770121
# 1               800     2770121
# ...

# %%
doners_data.columns
# Out:
# Index(['Sr No.', 'Reference No  (URN)', 'Journal Date', 'Date of\nPurchase',
#        'Date of Expiry', 'Name of the Purchaser', 'Prefix', 'Bond\nNumber',
#        'Denominations', 'Issue Branch Code', 'Issue Teller', 'Status'],
#       dtype='object')

# %%
doners_data.rename(columns = {'Reference No  (URN)':'ref_no', 'Journal Date':'journal_date', 'Date of\nPurchase':'purchase_date',
       'Date of Expiry':'expiry_date', 'Name of the Purchaser':'purchaser_name', 'Prefix':'prefix', 'Bond\nNumber':'bond_no',
       'Denominations':'denominations', 'Issue Branch Code':'issue_branch_code', 'Issue Teller':'issue_teller', 'Status':'status'},inplace = True)

# %%
receiver_data.columns
# Out:
# Index(['Sr No.', 'Date of\nEncashment', 'Name of the Political Party',
#        'Account no. of\nPolitical Party', 'Prefix', 'Bond\nNumber',
#        'Denominations', 'Pay Branch\nCode', 'Pay Teller'],
#       dtype='object')

# %%
receiver_data.rename(columns = {'Date of\nEncashment':'redemption_date', 'Name of the Political Party':'political_party_name',
       'Account no. of\nPolitical Party':'account_no_of_party', 'Prefix':'prifix', 'Bond\nNumber':'bond_no',
       'Denominations':'denominations', 'Pay Branch\nCode':'pay_branch_code', 'Pay Teller':'pay_teller'},inplace = True)

# %%
doners_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18871 entries, 0 to 18870
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Sr No.             18871 non-null  int64
#  1   ref_no             18871 non-null  object
#  2   journal_date       18871 non-null  datetime64[ns]
#  3   purchase_date      18871 non-null  datetime64[ns]
#  4   expiry_date        18871 non-null  datetime64[ns]
#  5   purchaser_name     18871 non-null  object
#  6   prefix             18871 non-null  object
#  7   bond_no            18871 non-null  int64
#  8   denominations      18871 non-null  int64
#  9   issue_branch_code  18871 non-null  int64
#  10  issue_teller       18871 non-null  int64
#  11  status             18871 non-null  object
# dtypes: datetime64[ns](3), int64(5), object(4)
# memory usage: 1.7+ MB

# %%
doners_data.describe()
# Out:
#              Sr No.                   journal_date  \
# count  18871.000000                          18871
# mean    9436.000000  2022-03-15 00:27:55.714058496
# min        1.000000            2019-04-12 00:00:00
# 25%     4718.500000            2021-04-09 00:00:00
# 50%     9436.000000            2022-07-06 00:00:00
# 75%    14153.500000            2023-07-10 00:00:00
# max    18871.000000            2024-01-11 00:00:00
# std     5447.732801                            NaN
#
#                        purchase_date                    expiry_date  \
# count                          18871                          18871
# mean   2022-03-15 00:28:27.763234304  2022-03-29 00:28:27.763234304
# min              2019-04-12 00:00:00            2019-04-26 00:00:00
# 25%              2021-04-09 00:00:00            2021-04-23 00:00:00
# 50%              2022-07-06 00:00:00            2022-07-20 00:00:00
# 75%              2023-07-10 00:00:00            2023-07-24 00:00:00
# ...

# %%
total_amount = doners_data['denominations'].sum()
total_amount_cr = total_amount / 10000000

total_amount_cr = round(total_amount_cr, 2)
print("Total Amount Of All Bond:", total_amount_cr,"Cr.")
# Out:
# Total Amount Of All Bond: 12155.51 Cr.

# %%
doners_data.sort_values(by="denominations",ascending=False)
# Out:
#        Sr No.                   ref_no journal_date purchase_date expiry_date  \
# 9435     9436  00691202207060000002469   2022-07-06    2022-07-06  2022-07-20
# 10946   10947  00300202211140000002648   2022-11-14    2022-11-14  2022-11-28
# 10934   10935  00691202211140000002654   2022-11-14    2022-11-14  2022-11-28
# 10935   10936  00691202211140000002654   2022-11-14    2022-11-14  2022-11-28
# 10936   10937  00691202211140000002654   2022-11-14    2022-11-14  2022-11-28
# ...       ...                      ...          ...           ...         ...
# 11173   11174  01355202211150000002713   2022-11-15    2022-11-15  2022-11-29
# 11172   11173  01355202211150000002713   2022-11-15    2022-11-15  2022-11-29
# 11704   11705  00691202301230000002781   2023-01-23    2023-01-23  2023-02-06
# 2432     2433  00300201905100000001430   2019-05-10    2019-05-10  2019-05-24
# 18402   18403  00001202401090000003675   2024-01-09    2024-01-09  2024-01-23
#
# ...

# %%
doners_data.sort_values(by="denominations",ascending=False)[['purchaser_name', 'denominations']].head()
# Out:
#                             purchaser_name  denominations
# 9435   FUTURE GAMING AND HOTEL SERVICES PR       10000000
# 10946                WELSPUN INDIA LIMITED       10000000
# 10934                      VEDANTA LIMITED       10000000
# 10935                      VEDANTA LIMITED       10000000
# 10936                      VEDANTA LIMITED       10000000

# %%
receiver_data['political_party_name'].unique()
# Out:
# array(['ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM',
#        'BHARAT RASHTRA SAMITHI', 'BHARATIYA JANATA PARTY',
#        'PRESIDENT, ALL INDIA CONGRESS COMMITTEE', 'SHIVSENA',
#        'TELUGU DESAM PARTY',
#        'YSR  CONGRESS PARTY  (YUVAJANA SRAMIKA RYTHU CONGRESS PARTY)',
#        'DRAVIDA MUNNETRA KAZHAGAM (DMK)', 'JANATA DAL ( SECULAR )',
#        'NATIONALIST CONGRESS PARTY MAHARASHTRA PRADESH',
#        'ALL INDIA TRINAMOOL CONGRESS', 'BIHAR PRADESH JANTA DAL(UNITED)',
#        'RASHTRIYA JANTA DAL', 'AAM AADMI PARTY',
#        'ADYAKSHA SAMAJVADI PARTY', 'SHIROMANI AKALI DAL',
#        'JHARKHAND MUKTI MORCHA', 'JAMMU AND KASHMIR NATIONAL CONFERENCE',
#        'BIJU JANATA DAL', 'GOA FORWARD PARTY',
#        'MAHARASHTRAWADI GOMNTAK PARTY', 'SIKKIM KRANTIKARI MORCHA',
#        'JANASENA PARTY', 'SIKKIM DEMOCRATIC FRONT'], dtype=object)

# %%
receiver_data.groupby(['political_party_name'])['denominations'].sum()
# Out:
# political_party_name
# AAM AADMI PARTY                                                   654500000
# ADYAKSHA SAMAJVADI PARTY                                          140500000
# ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM                           60500000
# ALL INDIA TRINAMOOL CONGRESS                                    16095314000
# BHARAT RASHTRA SAMITHI                                          12147099000
# BHARATIYA JANATA PARTY                                          60605111000
# BIHAR PRADESH JANTA DAL(UNITED)                                   140000000
# BIJU JANATA DAL                                                  7755000000
# DRAVIDA MUNNETRA KAZHAGAM (DMK)                                  6390000000
# GOA FORWARD PARTY                                                   3500000
# JAMMU AND KASHMIR NATIONAL CONFERENCE                               5000000
# JANASENA PARTY                                                    210000000
# ...

# %%
party_with_funds = pd.DataFrame(receiver_data.groupby(['political_party_name'])['denominations'].sum())

# %%
party_with_funds
# Out:
#                                                     denominations
# political_party_name
# AAM AADMI PARTY                                         654500000
# ADYAKSHA SAMAJVADI PARTY                                140500000
# ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM                 60500000
# ALL INDIA TRINAMOOL CONGRESS                          16095314000
# BHARAT RASHTRA SAMITHI                                12147099000
# BHARATIYA JANATA PARTY                                60605111000
# BIHAR PRADESH JANTA DAL(UNITED)                         140000000
# BIJU JANATA DAL                                        7755000000
# DRAVIDA MUNNETRA KAZHAGAM (DMK)                        6390000000
# GOA FORWARD PARTY                                         3500000
# JAMMU AND KASHMIR NATIONAL CONFERENCE                     5000000
# JANASENA PARTY                                          210000000
# JANATA DAL ( SECULAR )                                  435000000
# ...

# %%
party_with_funds.reset_index(inplace=True)

# %%
party_with_funds.columns
# Out:
# Index(['political_party_name', 'denominations'], dtype='object')

# %%
party_with_funds
# Out:
#                                  political_party_name  denominations
# 0                                     AAM AADMI PARTY      654500000
# 1                            ADYAKSHA SAMAJVADI PARTY      140500000
# 2            ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM       60500000
# 3                        ALL INDIA TRINAMOOL CONGRESS    16095314000
# 4                              BHARAT RASHTRA SAMITHI    12147099000
# 5                              BHARATIYA JANATA PARTY    60605111000
# 6                     BIHAR PRADESH JANTA DAL(UNITED)      140000000
# 7                                     BIJU JANATA DAL     7755000000
# 8                     DRAVIDA MUNNETRA KAZHAGAM (DMK)     6390000000
# 9                                   GOA FORWARD PARTY        3500000
# 10              JAMMU AND KASHMIR NATIONAL CONFERENCE        5000000
# 11                                     JANASENA PARTY      210000000
# 12                             JANATA DAL ( SECULAR )      435000000
# ...

# %%
party_with_funds['denominations'] =  party_with_funds['denominations'] / 10000000
party_with_funds['denominations'] = round(party_with_funds['denominations'], 2)
party_with_funds
# Out:
#                                  political_party_name  denominations
# 0                                     AAM AADMI PARTY          65.45
# 1                            ADYAKSHA SAMAJVADI PARTY          14.05
# 2            ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM           6.05
# 3                        ALL INDIA TRINAMOOL CONGRESS        1609.53
# 4                              BHARAT RASHTRA SAMITHI        1214.71
# 5                              BHARATIYA JANATA PARTY        6060.51
# 6                     BIHAR PRADESH JANTA DAL(UNITED)          14.00
# 7                                     BIJU JANATA DAL         775.50
# 8                     DRAVIDA MUNNETRA KAZHAGAM (DMK)         639.00
# 9                                   GOA FORWARD PARTY           0.35
# 10              JAMMU AND KASHMIR NATIONAL CONFERENCE           0.50
# 11                                     JANASENA PARTY          21.00
# 12                             JANATA DAL ( SECULAR )          43.50
# ...

# %%
doners_data.head()
# Out:
#    Sr No.                   ref_no journal_date purchase_date expiry_date  \
# 0       1  00001201904120000001166   2019-04-12    2019-04-12  2019-04-26
# 1       2  00001201904120000001166   2019-04-12    2019-04-12  2019-04-26
# 2       3  00001201904120000001166   2019-04-12    2019-04-12  2019-04-26
# 3       4  00001201904120000001166   2019-04-12    2019-04-12  2019-04-26
# 4       5  00001201904120000001166   2019-04-12    2019-04-12  2019-04-26
#
#         purchaser_name prefix  bond_no  denominations  issue_branch_code  \
# 0  A B C INDIA LIMITED     TL    11448        1000000                  1
# 1  A B C INDIA LIMITED     TL    11447        1000000                  1
# 2  A B C INDIA LIMITED     TL    11441        1000000                  1
# 3  A B C INDIA LIMITED     OL     1113         100000                  1
# 4  A B C INDIA LIMITED     OL     1118         100000                  1
#
#    issue_teller status
# 0       5899230   Paid
# 1       5899230   Paid
# ...

# %%
receiver_data.head()
# Out:
#    Sr No. redemption_date                      political_party_name  \
# 0       1      2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 1       2      2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 2       3      2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 3       4      2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 4       5      2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
#
#   account_no_of_party prifix  bond_no  denominations  pay_branch_code  \
# 0         *******5199     OC      775       10000000              800
# 1         *******5199     OC     3975       10000000              800
# 2         *******5199     OC     3967       10000000              800
# 3         *******5199     TL    10418        1000000              800
# 4         *******5199     TL      126        1000000              800
#
#    pay_teller
# 0     2770121
# 1     2770121
# 2     2770121
# 3     2770121
# 4     2770121

# %%
com_data = pd.merge(doners_data,receiver_data,on="bond_no",how="inner")
com_data

com_data.to_csv("Comb.csv")

# %%
com_data.columns
# Out:
# Index(['Sr No._x', 'ref_no', 'journal_date', 'purchase_date', 'expiry_date',
#        'purchaser_name', 'prefix', 'bond_no', 'denominations_x',
#        'issue_branch_code', 'issue_teller', 'status', 'Sr No._y',
#        'redemption_date', 'political_party_name', 'account_no_of_party',
#        'prifix', 'denominations_y', 'pay_branch_code', 'pay_teller'],
#       dtype='object')

# %%
com_info = com_data[['purchaser_name','bond_no','denominations_x','political_party_name']]
com_info
# Out:
#                                        purchaser_name  bond_no  \
# 0                                 A B C INDIA LIMITED    11448
# 1                                 A B C INDIA LIMITED    11448
# 2                         IFB AGRO INDUSTRIES LIMITED    11448
# 3                         IFB AGRO INDUSTRIES LIMITED    11448
# 4                                 A B C INDIA LIMITED    11447
# ...                                               ...      ...
# 28772  WESTERN UP POWER TRANSMISSION COMPANY LI MITED    17091
# 28773  WESTERN UP POWER TRANSMISSION COMPANY LI MITED    17087
# 28774  WESTERN UP POWER TRANSMISSION COMPANY LI MITED    17065
# 28775                  WESTWELL GASES PRIVATE LIMITED    17801
# 28776                  WESTWELL GASES PRIVATE LIMITED    17803
#
#        denominations_x                     political_party_name
# 0              1000000                   BHARATIYA JANATA PARTY
# 1              1000000  PRESIDENT, ALL INDIA CONGRESS COMMITTEE
# ...

# %%
bjp_data = com_info[com_info['political_party_name'] == 'BHARATIYA JANATA PARTY']
bjp_data.columns
# Out:
# Index(['purchaser_name', 'bond_no', 'denominations_x', 'political_party_name'], dtype='object')

# %%
bjp_info = pd.DataFrame(bjp_data.groupby('purchaser_name')['denominations_x'].sum())
top_5_bjp_doners = bjp_info.sort_values(by='denominations_x', ascending=False).head()
top_5_bjp_doners = top_5_bjp_doners.reset_index()

top_5_bjp_doners
# Out:
#                                    purchaser_name  denominations_x
# 0  MEGHA ENGINEERING AND INFRASTRUCTURES LI MITED       6010000000
# 1                   QWIKSUPPLYCHAINPRIVATELIMITED       5640000000
# 2                                 VEDANTA LIMITED       3229500000
# 3                           BHARTI AIRTEL LIMITED       1860000000
# 4                                   MADANLAL LTD.       1820000000

# %%
top_5_bjp_doners.to_csv(r"top_5_bjp_doner.csv")

# %%
unique_bond_no_doners = doners_data['bond_no'].unique()
unique_bond_no_receiver = receiver_data['bond_no'].unique()

# %%
unique_bond_no_doners = list(unique_bond_no_doners)
unique_bond_no_receiver = list(unique_bond_no_receiver)

diff = set(unique_bond_no_receiver) - set(unique_bond_no_doners)

len(diff)
# Out:
# 860

# %%
bond_diff = list(diff)
bond_not_found_in_doners = receiver_data[receiver_data['bond_no'].isin(diff)]
bond_not_found_in_doners
# Out:
#       Sr No. redemption_date                      political_party_name  \
# 0          1      2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 1          2      2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 2          3      2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 4          5      2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 5          6      2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# ...      ...             ...                                       ...
# 2801    2802      2019-04-25                    BHARATIYA JANATA PARTY
# 2804    2805      2019-04-25                    BHARATIYA JANATA PARTY
# 2853    2854      2019-04-25                                  SHIVSENA
# 2854    2855      2019-04-25                                  SHIVSENA
# 2855    2856      2019-04-25                                  SHIVSENA
#
#      account_no_of_party prifix  bond_no  denominations  pay_branch_code  \
# ...

# %%
bond_not_found_in_doners['denominations'].sum()
# Out:
# 5345110000
